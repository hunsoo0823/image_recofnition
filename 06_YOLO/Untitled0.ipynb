# %% [markdown]
# #1. Mount Drive

# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
# !cp -r /gdrive/MyDrive/darknet/trafficsign/ .

# %%
ls -al ./trafficsign/

# %%
weight_file ='./trafficsign/traffic-sign-yolo   '
