# %% [markdown]
# #1. Variables

# %%
score = 0

# %%
print(score)

# %%
score = 10

# %%
print(score)

# %%
score = 20

# %%
print(score)

# %% [markdown]
# #2 Data Type

# %%
level = 1

# %%
type(level)

# %%
angle = 35.45

# %%
print(angle)

# %%
type(angle)

# %%
name = "Jonathan"

# %%
print(name)

# %%
type(name)

# %%
sound = True

# %%
type(sound)
