# %% [markdown]
# #1. Mount Drive

# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
# !ls -al '/gdrive/My Drive/data'

# %% [markdown]
# #2. Korean Characters

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
# Import pyplot as a alias 'plt'
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# #3. Load Data

# %%
import pandas as pd

# %%
file = '/gdrive/My Drive/data/data_2020.csv'
data = pd.read_csv(file)

# %%
data.head()

# %%
data.info()

# %% [markdown]
# #4. Histgram

# %%
plt.figure(figsize=(20,10))
sns.histplot(data[data['도착영업소코드'] == 110]['통행시간'], color='green',label='목천')
sns.histplot(data[data['도착영업소코드'] == 125]['통행시간'], color='b',label='남구미')
sns.histplot(data[data['도착영업소코드'] == 140]['통행시간'], color='r',label='부산')
plt.legend(title='도착영업소코드')
plt.show()

# %% [markdown]
# #5. Box Plot

# %%
plt.figure(figsize=(20,10))
sns.set(style='ticks', palette='pastel')
#Draw a nested boxplot
sns.boxplot(x='도착영업소코드', y='통행시간', data=data)
plt.show()

# %%
data_statistics = data[data['도착영업소코드'] == 130]['통행시간'].describe()

# %%
data_statistics

# %%
plt.figure(figsize=(20,10))
sns.set(style='ticks', palette='pastel')
#Draw a nested boxplot
sns.boxplot(x='요일', y='통행시간', data=data)
plt.show()

# %%
# Configure figure size
plt.figure(figsize=(20,10))
sns.set(style="ticks", palette="pastel")
# Draw a nested boxplot to show Pace by Gender
sns.boxplot(x="집계시", y="통행시간",
            data=data)
plt.show()
